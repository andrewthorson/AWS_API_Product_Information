# %% [markdown]
# # Retrieving Product Information using AWS Product Advertising API - Part 2
# Now that the AWS Product Advertising API responses have been saved for each queried product(ASIN), the next step is to parse this information. The following fields will be needed for advertising purposes:
# 1. ASIN
# 2. Title
# 3. Brand
# 4. GTIN(s)
# 5. MPN/Model
# 6. Specifications/Details
# 7. Product Description
# 8. Features
# 9. Product Category
# 10. Stock Image(s)
#
# Information from the AWS Product Advertising API responses will be used to fill as many fields as possible.

# %% [markdown]
# ## Import Libraries, Packages, and Modules

# %%
# import libraries, packages, and modules
import pandas as pd # Data structures and data analysis tools library
from bs4 import BeautifulSoup # HTML and XML document parsing package
from re import search, sub

# %% [markdown]
# ## Construct pandas DataFrame from Tab-Seperated Values File of AWS Product Advertising API Responses by ASIN

# %%
# construct pandas DataFrame with data from tsv file of aws pa api responses by asin
column_number_with_ASIN = 0 # set this variable to the numberical value of the csv column containing the desired ASINs
asin_responses_df = pd.read_csv('aws_pa_item_attributes_responses.tsv', header=0, sep='\t')
print(asin_responses_df.shape) # print DataFrame Shape
asin_responses_df.head() # preview DataFrame
# Out:
# (107, 5)
#          asin                                item_attributes_xml  \
# 0  B004XC6GJ0  <?xml version="1.0" ?><html><body><itemlookupr...
# 1  B000P1DEHU  <?xml version="1.0" ?><html><body><itemlookupr...
# 2  B004NEUJKA  <?xml version="1.0" ?><html><body><itemlookupr...
# 3  B0011ULQNI  <?xml version="1.0" ?><html><body><itemlookupr...
# 4  B001O0DP48  <?xml version="1.0" ?><html><body><itemlookupr...
#
#                                 editorial_review_xml  \
# 0  <?xml version="1.0" ?><html><body><itemlookupr...
# 1  <?xml version="1.0" ?><html><body><itemlookupr...
# 2  <?xml version="1.0" ?><html><body><itemlookupr...
# 3  <?xml version="1.0" ?><html><body><itemlookupr...
# 4  <?xml version="1.0" ?><html><body><itemlookupr...
#
#                                           images_xml        date
# 0  <?xml version="1.0" ?><html><body><itemlookupr...  2019-01-29
# 1  <?xml version="1.0" ?><html><body><itemlookupr...  2019-01-29
# 2  <?xml version="1.0" ?><html><body><itemlookupr...  2019-01-29
# 3  <?xml version="1.0" ?><html><body><itemlookupr...  2019-01-29
# 4  <?xml version="1.0" ?><html><body><itemlookupr...  2019-01-29

# %% [markdown]
# ## Construct pandas DataFrame for the Desired Product Fields

# %%
aws_pa_product_data_df = pd.DataFrame(columns=['asin', 'title', 'brand', 'gtin', 'mpn_model', 'specs', 'description', 'features', 'category', 'image'])
aws_pa_product_data_df.head() # return dataframe head
# Out:
# Empty DataFrame
# Columns: [asin, title, brand, gtin, mpn_model, specs, description, features, category, image]
# Index: []

# %% [markdown]
# ## Define Functions for Parsing XML Data

# %%
# define function for parsing xml data to prevent script from breaking on error, returns blank string instead
def parse_xml(xml, elementstring):
    """
    Parses product attributes from xml data.
    """
    xml = BeautifulSoup(xml, 'lxml')
    try:
        if elementstring == 'image':
            return(xml.item.largeimage.url.text)
        elif elementstring == 'description':
            try:
                desc_string = xml.find_all('content')[0].get_text()
                return(desc_string[0:search('<', str(image_test.find_all('content')[0].text)).span()[0]])
            except:
                return(xml.find_all('content')[0].get_text())
        elif elementstring == 'features':
            feature_list = []
            for feature in xml.find_all('feature'):
                if 'warranty' in feature.text.lower():
                    pass
                elif 'report to amazon' in feature.text.lower():
                    pass
                else:
                    feature_list.append(feature.text)
            if len(feature_list) > 0:
                return(feature_list)
            else:
                return('')
        elif elementstring == 'mpn':
            model_mpn1 = str(xml.find_all('model')[0].text)
            model_mpn2 = str(xml.find_all('mpn')[0].text)
            if model_mpn1 != '':
                return(model_mpn1)
            else:
                return(model_mpn2)
        elif 'list' in elementstring:
            list_elements = []
            for list_item in xml.find(elementstring).findAll(elementstring + 'element', recursive=False):
                list_elements.append(list_item.text)
            return(list_elements)
        elif len(xml.find_all(elementstring)) > 1:
            list_elements = []
            for element in xml.find_all(elementstring):
                list_elements.append(element.text)
            return(list_elements)
        else:
            return(str(xml.find_all(elementstring)[0].text))
    except:
        return('')

# %%
# define function for parsing specifications from xml data to prevent script from breaking on error, returns blank string instead
def spec_parse_xml(xml):
    """
    Parses product specifications from xml data.
    """
    try:
        xml = BeautifulSoup(xml, 'lxml')
        field_spec_list = []
        specs_map_dict = {}
        for element in xml.itemattributes.children:
            if 'sku' in element.name.lower() or 'warranty' in element.name.lower() or 'feature' in element.name.lower() or 'legaldisclaimer' in element.name.lower() or 'language' in element.name.lower() or 'department' in element.name.lower() or 'dimensions' in element.name.lower() or 'title' in element.name.lower() or 'product' in element.name.lower():
                    pass
            elif 'listprice' in element.name.lower():
                pass
            elif 'list' in element.name.lower():
                specs_map_dict[element.name] = 'list'
            elif len(xml.find_all(element.name)) > 1:
                specs_map_dict[element.name] = 'multi'
            else:
                specs_map_dict[element.name] = 'single'
        for attrib in specs_map_dict:
            specs_value_list = []
            if specs_map_dict[attrib] == 'list':
                if attrib == 'catalognumberlist':
                    for cn in xml.catalognumberlist.children:
                        specs_value_list.append(cn.text)
                    specs_map_dict[attrib] = list(set(specs_value_list))
                elif attrib == 'eanlist':
                    for cn in xml.eanlist.children:
                        specs_value_list.append(cn.text)
                    specs_map_dict[attrib] = list(set(specs_value_list))
                elif attrib == 'upclist':
                    for cn in xml.eanlist.children:
                        specs_value_list.append(cn.text)
                    specs_map_dict[attrib] = list(set(specs_value_list))
            elif specs_map_dict[attrib] == 'multi':
                for value in xml.find_all(attrib):
                    specs_value_list.append(value.text)
                specs_map_dict[attrib] = list(set(specs_value_list))
            elif specs_map_dict[attrib] == 'single':
                specs_map_dict[attrib] = xml.find_all(attrib)[0].text
            else:
                pass
        for key in specs_map_dict:
            dict_string = ''
            dict_string += key + ': '
            if type(specs_map_dict[key]) == list:
                    for i, list_items in enumerate(specs_map_dict[key]):
                        if i < len(specs_map_dict[key]) - 1:
                            dict_string += list_items + ', '
                        else:
                            dict_string += list_items
            else:
                dict_string += specs_map_dict[key]
            field_spec_list.append(dict_string)
        return(field_spec_list)
    except:
        return('')

# %%
# define function for construction product category taxonomy
def cat_taxonomy(productgroup, producttype):
    """
    Constructs product taxonomy from provided arguments
    """
    cat_string = '{} > {}'.format(productgroup, producttype)
    if cat_string == ' > ':
        return('')
    else:
        return(cat_string)

# %%
# construct product class
class product:
    """
    Class constructs product object and defines the objects product attributes
    """
    def __init__(self, item_attributes_xml, editorial_review_xml, images_xml):
        self.ia_xml = item_attributes_xml
        self.i_xml = images_xml
        self.er_xml = editorial_review_xml
        self.image = parse_xml(self.i_xml, 'image')
        self.description = parse_xml(self.er_xml, 'description')
        self.asin = parse_xml(self.ia_xml, 'asin')
        self.title = parse_xml(self.ia_xml, 'title')
        self.brand = parse_xml(self.ia_xml, 'brand')
        self.upc = parse_xml(self.ia_xml, 'upc')
        self.ean = parse_xml(self.ia_xml, 'ean')
        self.isbn = parse_xml(self.ia_xml, 'isbn')
        self.mpn = parse_xml(self.ia_xml, 'mpn')
        self.model = parse_xml(self.ia_xml, 'model')
        self.features = parse_xml(self.ia_xml, 'features')
        self.department = parse_xml(self.ia_xml, 'department')
        self.group = parse_xml(self.ia_xml, 'productgroup')
        self.type = parse_xml(self.ia_xml, 'producttypename')
        self.specs = spec_parse_xml(self.ia_xml)

# %%
# function for iterating through each product
def parse_loop(df, column_names):
    """
    1. Takes DataFrame of product xml data.
    2. Iterates through rows creating an object of the product class.
    3. Constructs a dictionary from the object attributes.
    4. Returns a DataFrame of desired product fields.
    """
    new_df = pd.DataFrame(columns=column_names)
    for row in df.iterrows():
        catalog_dict = {}
        catalog_item = product(row[1][1], row[1][2], row[1][3])
        catalog_dict = {
            'asin' : row[1][0],
            'title' : catalog_item.title,
            'brand' : catalog_item.brand,
            'gtin' : catalog_item.ean,
            'mpn_model' : catalog_item.mpn,
            'specs' : catalog_item.specs,
            'description' : catalog_item.description,
            'features' : catalog_item.features,
            'category' : cat_taxonomy(catalog_item.group, catalog_item.type),
            'image' : catalog_item.image,
        }
        new_df = new_df.append(catalog_dict, ignore_index=True)
    return(new_df)

# %% [markdown]
# ## Construct DataFrame of Product Data

# %%
# Construct DataFrame of Product Data 
aws_pa_product_data_df = parse_loop(asin_responses_df, aws_pa_product_data_df.columns)
aws_pa_product_data_df
# Out:
#            asin                                              title  \
# 0    B004XC6GJ0  ARRIS SURFboard SB6121 4x4 DOCSIS 3.0 Cable Mo...
# 1    B000P1DEHU  Sony DVD/VCR Progressive Scan Combo Player SLV...
# 2    B004NEUJKA  Uniden D1660-2 DECT6.0 Caller ID Cordless hand...
# 3    B0011ULQNI
# 4    B001O0DP48  Uniden DECT 6.0 Silver Cordless Phone with Cal...
# 5    B00DQV2BDO          Panasonic KX-TGA402N 1.9GHz Extra Handset
# 6    B000E1B2SO
# 7    B00005K3B1  Uniden EXA2950 900 MHz Cordless Phone with Dig...
# 8    B00000J0E6    RCA VHS Rewinder (Discontinued by Manufacturer)
# 9    B0001B86GI  Uniden DCX640 2.4 GHz Accessory Handset for DC...
# 10   B075X4G51V               Kinyo AW600A VHS Video Tape Rewinder
# 11   B006N9ZZS4  Polycom VVX 500 12-line Business Media Phone P...
# 12   B003A1LK1O  eMachines PS/2 Multimedia Black & Silver Keybo...
# 13   B00NIAYOX8  RCA Remote R130c1 for L32wd12 L32wd12yx7 L37wd...
# 14   B00IO3AQC2  Orion "OEM" 076N0EA010 VCR2511 VCR2510C VHSA66...
# 15   B0028MD7F8   LG Electronics/Zenith AKB69680401 REMOTE CONTROL
# 16   B001DFH0C2           Sony Remote Commander (RM-Y906), RM-Y906
# 17   B001DFPR9A  SONY 1-480-097-11 REMOTE CONTROL RM-AAU013 OEM...
# 18   B00A4U1XVQ   Panasonic PVQV201 PVV402 PVV4021 LSSQ0263 Remote
# 19   B0091HQHZU  Genuine HP 0957-2259 AC Power Supply Adapter +...
# 20   B00WLJLYJY  Power Supply AC ADAPTER 22V 455mA 3Pin for HP ...
# 21   B000IJEZI6  Philips SWS2102W/17 RF Modulator Video Convert...
# 22   B00PVV543G  Texas Instruments TI-36X Pro Scientific Calcul...
# 23   B077ZKF9XK  Lenovo New Genuine ThinkPad Yoga 45 Watt AC Ad...
# 24   B0036RH2U0           NETGEAR XAV2001 Powerline AV 200 Adapter
# 25   B004FWOECY             TomTom XL 335SE 4.3-Inch GPS Navigator
# 26   B0057OCS9A
# 27   B0015F0A8G
# 28   B000046S41                           Nintendo 64 Transfer Pak
# 29   B004RZJ60O                    Polaroid Impulse Instant Camera
# ..          ...                                                ...
# 77   6300247163                            The Turning Point [VHS]
# 78   B000056VP3                          Remember the Titans [VHS]
# 79   6302415853                           Dances With Wolves [VHS]
# 80   B000EFNVB6              SONY T120V - Sony S-VHS Videocassette
# 81   6301914090                              Days of Thunder [VHS]
# 82   6302428122                          Bill Cosby, Himself [VHS]
# 83   0783219105                                Happy Gilmore [VHS]
# 84   0790739305                    Why Do Fools Fall in Love [VHS]
# 85   0790738074                                The Music Man [VHS]
# 86   6302226899                      Best Years of Our Lives [VHS]
# 87   B000068CNG  Panasonic KX-TG2700S 2.4 GHz DSS Expandable Co...
# 88   B00008Y2EN  Uniden EXP3241 2.4 GHz Extended Range Cordless...
# 89   B001DFOBIS                Sony 1-418-694-11 REMOTE(RMT-V266A)
# 90   B001QPT1PI                                Homedics Ac Adapter
# 91   B003BNY7R0  VTech 6305 Accessory Cordless Handset, Silver/...
# 92   B00KZPD0D4      Genuine Hon-Kwang D0660 AC Adapter 6VDC 600mA
# 93   B005GY3GWO  Fuji AC-5VW AC Power Adapter for Fujifilm Digi...
# 94   B00997KEZQ  Pitney Bowes Power Supply AC Adapter 24VDC 1.5...
# 95   B0001BRIBM   Belkin ERGOBOARD PRO KEYBOARD BLACK (F8E887-BLK)
# 96   B0000950SC  Panasonic KX-TG5110M 5.8 GHz DSS Expandable Co...
# 97   B001ELLMGU        Sony RM-SC3 Factory Original Remote Control
# 98   B001K5NSYE           Sony 148057011 REMOTE CONTROL (RMADU007)
# 99   B0000C7AFN                       Minolta Vectis 40 APS Camera
# 100  B002VR6A9K  Microsoft Arc Wireless Keyboard for PC and Xbo...
# 101  B000F49ZHU  Panasonic KX-TG5623B Black 5.8 GHz FHSS GigaRa...
# 102  B0073W703I  Panasonic KX-TG4733B DECT 6.0 Cordless Phone w...
# 103  B00VU68JWE  Panasonic RR-930 MicroCassette Transcriber by ...
# 104  B003V865PC  The Sharper Image Smart Universal Jumbo Remote...
# 105  B008DGFPB2                      Texas Instruments Ti-5032 SVC
# 106  B00000K132         Brother PT-1800 Electronic Labeling System
#
#                                     brand           gtin  \
# 0                                   ARRIS  0168141495601
# 1                                    Sony  0027242708952
# 2                                  Uniden  0999993504940
# 3
# 4                                  Uniden  0050633271667
# 5                               Panasonic  0037988482528
# 6
# 7                                  Uniden  0050633151624
# 8                                     RCA  0079000309598
# 9                                  Uniden  0050633320129
# 10                                  Kinyo  0031752160506
# 11                                Polycom  0801964781178
# 12                              eMachines
# 13                                    RCA  0741725317195
# 14                                  ORION  0634173081957
# 15            LG Electronics Incorporated
# 16                                   Sony  5704327760481
# 17                                   Sony  5704327232209
# 18                              Panasonic  0723905218522
# 19                                     HP  5060301841240
# 20                                     HP  0666230470992
# 21                                PHILIPS  0609585151833
# 22                      Texas Instruments  0666672977165
# 23                                 Lenovo  0689227634450
# 24                                NETGEAR  0606449066456
# 25                                 TomTom
# 26
# 27
# 28                               Nintendo  0045496860219
# 29                               Polaroid
# ..                                    ...            ...
# 77                                         9786300247161
# 78                                         9780788828577
# 79                                         9786302415858
# 80                                   Sony  0027242430365
# 81                                         9786301914093
# 82                                         9786302428124
# 83   Universal Studios Home Entertainment  9780783219103
# 84                                         9780790739304
# 85                                         9780790738079
# 86                                         9786302226898
# 87                              Panasonic  0037988472949
# 88                                 Uniden  0050633300152
# 89                                   Sony  7532005228200
# 90                               Homedics
# 91                                  VTech  0601000749557
# 92                              Hon-Kwang  0192547641294
# 93
# 94
# 95                                 Belkin  0722868332788
# 96                              Panasonic  0037988473649
# 97                                   Sony  0888511008131
# 98                                   Sony  0887513458555
# 99                                         0043325330025
# 100                             Microsoft  0100177260815
# 101                             Panasonic  0037988476589
# 102                             Panasonic  0151903464458
# 103                             Panasonic  0074927910919
# 104                         Sharper Image  0084997006337
# 105                     Texas Instruments  0089612022778
# 106                 Brother International  0012502525882
#
#                    mpn_model  \
# 0                     SB6121
# 1    LYSB000P1DEHU-ELECTRNCS
# 2                    D1660-2
# 3
# 4                 DECT1560-2
# 5
# 6
# 7                   EXA-2950
# 8    Video Rewinder -Machine
# 9                     DCX640
# 10
# 11            2200-44500-025
# 12                   KB-0108
# 13
# 14
# 15
# 16                 141846911
# 17                 148009711
# 18
# 19                 0957-2259
# 20
# 21               SWS2102W/17
# 22           36PRO/TBL/1L1/A
# 23               00HM612-RFB
# 24            XAV2001-100NAS
# 25                   XL335SE
# 26
# 27
# 28
# 29
# ..                       ...
# 77
# 78
# 79
# 80                 FBA_39907
# 81
# 82
# 83
# 84
# 85
# 86
# 87                KX-TG2700S
# 88                   EXP3241
# 89
# 90                     ADP-1
# 91                      6305
# 92
# 93
# 94
# 95                F8E887-BLK
# 96                KX-TG5110M
# 97                    RM-SC3
# 98                4330952822
# 99                  2201-451
# 100                J5D-00001
# 101               KX-TG5623B
# 102                KXTG4733B
# 103                   RR-930
# 104               4330958114
# 105              Ti-5032 SVC
# 106                  PT-1800
#
#                                                  specs  \
# 0    [binding: Personal Computers, brand: ARRIS, ca...
# 1    [binding: Electronics, brand: Sony, ean: 00272...
# 2    [binding: Office Product, brand: Uniden, catal...
# 3
# 4    [binding: Office Product, brand: Uniden, catal...
# 5    [binding: Office Product, brand: Panasonic, ea...
# 6
# 7    [binding: Office Product, brand: Uniden, catal...
# 8    [binding: Electronics, brand: RCA, catalognumb...
# 9    [binding: Office Product, brand: Uniden, catal...
# 10   [binding: Electronics, brand: Kinyo, ean: 0031...
# 11   [aspectratio: 4:3, binding: Electronics, brand...
# 12   [binding: Personal Computers, brand: eMachines...
# 13   [binding: Electronics, brand: RCA, ean: 074172...
# 14   [binding: Electronics, brand: ORION, ean: 0634...
# 15   [binding: Electronics, brand: LG Electronics I...
# 16   [binding: Electronics, brand: Sony, ean: 57043...
# 17   [binding: Electronics, brand: Sony, ean: 57043...
# 18   [binding: Electronics, brand: Panasonic, ean: ...
# 19   [binding: Personal Computers, brand: HP, ean: ...
# 20   [binding: Electronics, brand: HP, ean: 0666230...
# 21   [binding: Electronics, brand: PHILIPS, color: ...
# 22   [author: n/a, binding: Office Product, brand: ...
# 23   [binding: Personal Computers, brand: Lenovo, e...
# 24   [binding: Personal Computers, brand: NETGEAR, ...
# 25   [binding: Electronics, brand: TomTom, label: T...
# 26
# 27
# 28   [binding: Video Game, brand: Nintendo, catalog...
# 29   [binding: Electronics, brand: Polaroid, label:...
# ..                                                 ...
# 77   [actor: Mikhail Baryshnikov, Anne Bancroft, Le...
# 78   [actor: Wood Harris, Donald Faison, Will Patto...
# 79   [actor: Rodney A. Grant, Floyd 'Red Crow' West...
# 80   [binding: Electronics, brand: Sony, ean: 00272...
# 81   [actor: Nicole Kidman, Cary Elwes, Randy Quaid...
# 82   [actor: Bill Cosby, audiencerating: PG (Parent...
# 83   [actor: Julie Bowen, Adam Sandler, Christopher...
# 84   [actor: Halle Berry, Lela Rochon, Larenz Tate,...
# 85   [actor: Hermione Gingold, Buddy Hackett, Rober...
# 86   [actor: Fredric March, Teresa Wright, Virginia...
# 87   [binding: Office Product, brand: Panasonic, ca...
# 88   [binding: Office Product, brand: Uniden, catal...
# 89   [binding: Electronics, brand: Sony, ean: 75320...
# 90   [binding: Electronics, brand: Homedics, label:...
# 91   [binding: Office Product, brand: VTech, catalo...
# 92   [binding: Electronics, brand: Hon-Kwang, ean: ...
# 93   [binding: Electronics, label: FUJIFILM, manufa...
# 94   [binding: Electronics, label: Pitney Bowes, ma...
# 95   [binding: Personal Computers, brand: Belkin, c...
# 96   [binding: Office Product, brand: Panasonic, ca...
# 97   [binding: Electronics, brand: Sony, ean: 08885...
# 98   [binding: Electronics, brand: Sony, ean: 08875...
# 99   [binding: Camera, catalognumberlist: 004332533...
# 100  [binding: Personal Computers, brand: Microsoft...
# 101  [binding: Office Product, brand: Panasonic, ca...
# 102  [binding: Office Product, brand: Panasonic, ca...
# 103  [binding: Personal Computers, brand: Panasonic...
# 104  [binding: Electronics, brand: Sharper Image, e...
# 105  [binding: Office Product, brand: Texas Instrum...
# 106  [binding: Office Product, brand: Brother Inter...
#
#                                            description  \
# 0    A new and improved version of the world's most...
# 1    Sony's SLV-D281P simplifies your home theater ...
# 2    You'll love that this Uniden Caller ID/ Call W...
# 3
# 4    Advanced DECT 6.0 technology operates on the n...
# 5    This auction is for the handset only. Charger,...
# 6
# 7    For a busy home or office, consider the Uniden...
# 8    RCA UVR1Q Features: Quickly Rewinds VHS Video ...
# 9    2.4GHz Accessory Handset - 2.4GHz Accessory ha...
# 10
# 11   VVX500 12 line Business Media -A performance b...
# 12   eMachines PS/2 Multimedia Keyboard\n\nFeatures...
# 13
# 14   This is a used remote control that is in good ...
# 15   THE LG ELECTRONICS/ZENITH AKB69680401 REMOTE C...
# 16   THE SONY 1-418-469-11 REMOTE CONTROL ALLOWS EA...
# 17                      STANDARD COMMANDER (RM-AAU013)
# 18   This is a used Remote Control that is in good ...
# 19   List of compatible models includes: SJ Ent 700...
# 20   UpBrightÂ® NEW Global Genuine OEM Original 22V...
# 21   Solves the problem of connecting components wi...
# 22   TI's most advanced scientific calculator is id...
# 23   New Genuine Lenovo ThinkPad Yoga 45 Watt AC Ad...
# 24   NETGEAR's Powerline AV 200 Adapter extends a h...
# 25   Keep your eyes safely on the road with the Tom...
# 26
# 27
# 28   With Nintendo's Transfer Pak, you can share in...
# 29   This impulse camera is in excellent condition....
# ..                                                 ...
# 77   Mikhail Baryshnikov made his film debut in thi...
# 78   Celebration of The Human Spirit, Filled with H...
# 79   Lt. John Dunbar, exiled to a remote western Ci...
# 80           VHS Tape, 2 Hours to 6 Hours of Recording
# 81           VHS - NO RETURNS ACCEPTED, NO EXCEPTIONS.
# 82   One of America's most popular comedians, Bill ...
# 83   Heavy-metal golf with Adam Sandler, a 1996 dry...
# 84   Music-based romantic drama about the late sing...
# 85   The Music Man was one of the last great movie ...
# 86   Winner of seven Academy Awards, including best...
# 87   Panasonic 2.4GHz Cordless System - Single-line...
# 88   2.4GHz Uniden in BLACK - 2.4GHz cordless - One...
# 89                                  REMOTE TRANSMITTER
# 90   MODEL: ADP-1\n\nTYPE: D12-1200\n\nINPUT: 120VA...
# 91   VTech 6305 Accessory Handset with Caller ID an...
# 92               Hon-Kwang D0660 6VDC 600mA AC adapter
# 93        AC POWER ADAPTER FOR FUJIFILM DIGITAL CAMERA
# 94   This is a Genuine Original Pitney Bowes A82415...
# 95   The ErgoBoard Pro Keyboard with USB Ports give...
# 96   Panasonic KX-TG5110M is a state-of-the-art cor...
# 97   THE SONY 1-478-518-21 REMOTE CONTROL ALLOWS EA...
# 98   THE SONY 148057011 REMOTE CONTROL ALLOWS EASY ...
# 99   Minolta Vectis 40 is a high performance zoom c...
# 100  Style that works. Meet the Arc Keyboard with b...
# 101  5.8 GHz FHSS GigaRange  Dual-Handset Phone Sys...
# 102  Panasonic High Quality Phone System with Answe...
# 103  Panasonic Transcriber - RR-930 - MicroCassette...
# 104  The Sharper Image Universal Jumbo Remote Contr...
# 105
# 106  Perfect labeler for office use. Uses 4 tape si...
#
#                                               features  \
# 0    [Compatible with Time Warner Cable, Charter, C...
# 1    [Combination DVD Player and Hi-Fi VCR - Compon...
# 2    [Digital DECT 6.0 for superior clarity, securi...
# 3
# 4    [DECT 6.0 Interference Free Cordless Frequency...
# 5    [DECT 6.0 Plus Technology  - Interference Free...
# 6
# 7    [900 MHz cordless phone with digital answering...
# 8                                 [1-Way VHS Rewinder]
# 9    [2.4 GHz digital signal; includes charger base...
# 10   [Saves wear and tear on your VCR, Quick rewind...
# 11   [3.5'' (9-cm) TFT Touchscreen Display (320 x 2...
# 12   [Black with Silver Hot Keys, Low Noise, Low Pr...
# 13   [tested, sold as pictured, Free Batteries, cle...
# 14                                    [Fast Shipping!]
# 15   [THE LG ELECTRONICS/ZENITH AKB69680401 REMOTE ...
# 16   [THE SONY 1-418-469-11 REMOTE CONTROL ALLOWS E...
# 17   [THE SONY 148009711 REMOTE CONTROL ALLOWS EASY...
# 18
# 19
# 20   [World Wide Input Voltage 100-240VAC 50/60Hz, ...
# 21   [Color coded inputs, Quality construction, S-V...
# 22                                      [DRP-TI36XPRO]
# 23
# 24   [Extends a high speed Internet connection to a...
# 25   [TomTom 4.3-inch GPS touchscreen interface, An...
# 26
# 27
# 28
# 29   [Excellent Condition, Fully Functional, Lens i...
# ..                                                 ...
# 77
# 78                            [Condition: Used - Good]
# 79                          [Dances With Wolves [VHS]]
# 80   [Sold as 1 EA, Repeated Record/Erase Cycles, 0...
# 81         [VHS - NO RETURNS ACCEPTED, NO EXCEPTIONS.]
# 82
# 83
# 84
# 85
# 86
# 87   [2.4 GHz frequency hopping digital spread spec...
# 88   [2.4 GHz analog operation, 20-channel auto-sca...
# 89   [REMOTE TRANSMITTER, Works with the following ...
# 90   [INPUT: 120VAC 60Hz 26W, OUTPUT: 12VDC 1200mA,...
# 91   [DECT 6.0 Digital Technology, Interference fre...
# 92   [Hon-Kwang D0660 AC Adapter 6VDC 600mA, Input:...
# 93                             [Fuji AC Power Adapter]
# 94   [A Genuine Original Pitney Bowes A82415D Power...
# 95   [Main Specifications Product Description Belki...
# 96   [5.8 GHz DSS operation, 2 handsets included; e...
# 97   [No Programming required, Guaranteed to work r...
# 98   [THE SONY 148057011 REMOTE CONTROL ALLOWS EASY...
# 99
# 100  [Revolutionary ergonomic design, Features 4 pr...
# 101  [5.8 GHz Frequency-hopping spread spectrum FHS...
# 102  [DECT 6.0 Plus Technology, 3 Cordless Handsets...
# 103  [We offer a complete unconditional guarantee o...
# 104  [DVD, TV, DVR, CABLE, SATELLITE, AUDIO...Contr...
# 105  [Desktop/Portable, Display Digits: 10, Batteri...
# 106  [Laminated tape for durability, Multiline prin...
#
#                                               category  \
# 0                           CE > COMPUTER_INPUT_DEVICE
# 1                                             CE > VCR
# 2                                           CE > PHONE
# 3
# 4                                           CE > PHONE
# 5                              CE > OFFICE_ELECTRONICS
# 6
# 7                                           CE > PHONE
# 8                               Speakers > BLANK_MEDIA
# 9                                           CE > PHONE
# 10                             Speakers > CE_ACCESSORY
# 11                                          CE > PHONE
# 12                            PC Accessory > KEYBOARDS
# 13                           Speakers > REMOTE_CONTROL
# 14                           Speakers > REMOTE_CONTROL
# 15                                 CE > REMOTE_CONTROL
# 16                           Speakers > REMOTE_CONTROL
# 17                           Speakers > REMOTE_CONTROL
# 18                           Speakers > REMOTE_CONTROL
# 19                             PC Accessory > COMPUTER
# 20                                        CE > BATTERY
# 21                                   CE > CE_ACCESSORY
# 22                                CE > OFFICE_PRODUCTS
# 23                   PC Accessory > COMPUTER_COMPONENT
# 24                              CE > NETWORKING_DEVICE
# 25   GPS or Navigation System > GPS_OR_NAVIGATION_S...
# 26
# 27
# 28                      Video Games > ABIS_VIDEO_GAMES
# 29                           Photography > CAMERA_FILM
# ..                                                 ...
# 77                                  Video > ABIS_VIDEO
# 78                                  Video > ABIS_VIDEO
# 79                                  Video > ABIS_VIDEO
# 80                                    CE > BLANK_MEDIA
# 81                                    Video > ABIS_DVD
# 82                                  Video > ABIS_VIDEO
# 83                                  Video > ABIS_VIDEO
# 84                                  Video > ABIS_VIDEO
# 85                                  Video > ABIS_VIDEO
# 86                                  Video > ABIS_VIDEO
# 87                                          CE > PHONE
# 88                                          CE > PHONE
# 89                           Speakers > REMOTE_CONTROL
# 90                                  Speakers > BATTERY
# 91                                          CE > PHONE
# 92                                  Speakers > BATTERY
# 93                                  Speakers > BATTERY
# 94                                  Speakers > BATTERY
# 95                                      CE > KEYBOARDS
# 96                                          CE > PHONE
# 97                           Speakers > REMOTE_CONTROL
# 98                           Speakers > REMOTE_CONTROL
# 99                           Photography > CAMERA_FILM
# 100                                     CE > KEYBOARDS
# 101                                         CE > PHONE
# 102                                         CE > PHONE
# 103                Office Product > COMPUTER_COMPONENT
# 104                                CE > REMOTE_CONTROL
# 105                               CE > OFFICE_PRODUCTS
# 106                            CE > OFFICE_ELECTRONICS
#
#                                                  image
# 0    https://images-na.ssl-images-amazon.com/images...
# 1    https://images-na.ssl-images-amazon.com/images...
# 2    https://images-na.ssl-images-amazon.com/images...
# 3
# 4    https://images-na.ssl-images-amazon.com/images...
# 5    https://images-na.ssl-images-amazon.com/images...
# 6
# 7    https://images-na.ssl-images-amazon.com/images...
# 8    https://images-na.ssl-images-amazon.com/images...
# 9    https://images-na.ssl-images-amazon.com/images...
# 10   https://images-na.ssl-images-amazon.com/images...
# 11   https://images-na.ssl-images-amazon.com/images...
# 12   https://images-na.ssl-images-amazon.com/images...
# 13   https://images-na.ssl-images-amazon.com/images...
# 14   https://images-na.ssl-images-amazon.com/images...
# 15   https://images-na.ssl-images-amazon.com/images...
# 16   https://images-na.ssl-images-amazon.com/images...
# 17   https://images-na.ssl-images-amazon.com/images...
# 18   https://images-na.ssl-images-amazon.com/images...
# 19   https://images-na.ssl-images-amazon.com/images...
# 20   https://images-na.ssl-images-amazon.com/images...
# 21   https://images-na.ssl-images-amazon.com/images...
# 22   https://images-na.ssl-images-amazon.com/images...
# 23   https://images-na.ssl-images-amazon.com/images...
# 24   https://images-na.ssl-images-amazon.com/images...
# 25   https://images-na.ssl-images-amazon.com/images...
# 26
# 27
# 28   https://images-na.ssl-images-amazon.com/images...
# 29   https://images-na.ssl-images-amazon.com/images...
# ..                                                 ...
# 77   https://images-na.ssl-images-amazon.com/images...
# 78   https://images-na.ssl-images-amazon.com/images...
# 79   https://images-na.ssl-images-amazon.com/images...
# 80   https://images-na.ssl-images-amazon.com/images...
# 81   https://images-na.ssl-images-amazon.com/images...
# 82   https://images-na.ssl-images-amazon.com/images...
# 83   https://images-na.ssl-images-amazon.com/images...
# 84   https://images-na.ssl-images-amazon.com/images...
# 85   https://images-na.ssl-images-amazon.com/images...
# 86   https://images-na.ssl-images-amazon.com/images...
# 87   https://images-na.ssl-images-amazon.com/images...
# 88   https://images-na.ssl-images-amazon.com/images...
# 89
# 90   https://images-na.ssl-images-amazon.com/images...
# 91   https://images-na.ssl-images-amazon.com/images...
# 92   https://images-na.ssl-images-amazon.com/images...
# 93   https://images-na.ssl-images-amazon.com/images...
# 94   https://images-na.ssl-images-amazon.com/images...
# 95   https://images-na.ssl-images-amazon.com/images...
# 96   https://images-na.ssl-images-amazon.com/images...
# 97   https://images-na.ssl-images-amazon.com/images...
# 98   https://images-na.ssl-images-amazon.com/images...
# 99   https://images-na.ssl-images-amazon.com/images...
# 100  https://images-na.ssl-images-amazon.com/images...
# 101  https://images-na.ssl-images-amazon.com/images...
# 102  https://images-na.ssl-images-amazon.com/images...
# 103  https://images-na.ssl-images-amazon.com/images...
# 104  https://images-na.ssl-images-amazon.com/images...
# 105  https://images-na.ssl-images-amazon.com/images...
# 106  https://images-na.ssl-images-amazon.com/images...
#
# [107 rows x 10 columns]

# %% [markdown]
# ## Save aws_pa_product_data_df state in a Tab-delimited values file
# As this process may be repeated over time and existing data may remain useful, the mode is set to 'a' for append.

# %%
# save as tsv
aws_pa_product_data_df.to_csv('aws_pa_product_data.tsv', sep='\t' , index=False, mode='a')
print('Export complete.')
# Out:
# Export complete.

# %% [markdown]
# ## Construct List of Products Missing the Title Field

# %%
# Construct List of Products Missing the Title Field
aws_pa_product_data_missing_df = aws_pa_product_data_df['asin'][aws_pa_product_data_df['title'] == '']
aws_pa_product_data_missing_df
# Out:
# 3     B0011ULQNI
# 6     B000E1B2SO
# 26    B0057OCS9A
# 27    B0015F0A8G
# 42    B00006IIOL
# 44    B0007Z70YM
# 46    B000Q8UPKQ
# Name: asin, dtype: object

# %% [markdown]
# ## Results

# %%
# Number of Products with Title Present
total = aws_pa_product_data_df.shape[0]
title_present = aws_pa_product_data_df['asin'][aws_pa_product_data_df['title'] != ''].shape[0]
title_absent = aws_pa_product_data_df['asin'][aws_pa_product_data_df['title'] == ''].shape[0]
print('Number of Product Rows with Title Present: ' + str(title_present))
print('Number of Product Rows with Title Absent: ' + str(title_absent))
print('Total Number of Product Rows: ' + str(total))
print('Success Rate: ' + str(round(title_present / total * 100, 2)) + '%')
# Out:
# Number of Product Rows with Title Present: 100
# Number of Product Rows with Title Absent: 7
# Total Number of Product Rows: 107
# Success Rate: 93.46%

# %% [markdown]
# ## Discussion

# %% [markdown]
# This was the second part of a two part project. The goal of parsing the desired product fields was largely successful. As depicted in the <i>aws_pa_product_data_missing_df</i> DataFrame, data about some products is unavailable for retrieval via the Amazon Web Services Product Advertising API. Consequently, data for these products will need to be obtained from a different source. One alternative source that may be useful is eBay. A future project may address these shortcomings in the interest of improving data quality and completeness. This project was successful with at  93.46% of products now being matched with at least a product title.
